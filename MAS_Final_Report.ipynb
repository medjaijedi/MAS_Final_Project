# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science','notebook','grid'])
from scipy import integrate
import control as ct

# %% [markdown]
# ![network.png](attachment:network.png)
#
# Network of the system under consideration

# %%
#system Mhat matrix
Mhat = np.array([[2,0,-1,0,-1], [0,3,-1,-1,-1],[-1,-1,3,-1,0],[0,-1,-1,4,-1],[-1,-1,0,-1,4]])
E,V = np.linalg.eig(Mhat)
print(E)
# Out:
# [0.32918547 2.13832889 5.58170567 4.50278793 3.44799204]

# %%
#Defining the system matrices:
A = np.array([[0, 1], [-1, 0]])
B1 = np.array([[0], [1]])
B2 = np.array([[0], [1]])
C = np.array([[1, 0]])
D11 = np.array([[0]])
